# %%
from torch.utils.data import Dataset, Subset, DataLoader
from torch_geometric.loader import DataLoader as GraphDataLoader
import typing as tp
import torch

# %%
import numpy as np
import h5py as h5
import matplotlib.pyplot as plt
import seaborn as sns

# %%
source_path = "/home/plotnikovgp/baikal/data/baikal_multi_0324_flat_treck-cascade_h8_s2_pureMC_normed.h5"
target_path = "/home/plotnikovgp/baikal/data/exp.h5"

# %%
hfile1 = h5.File(source_path, 'r')
hfile2 = h5.File(target_path, 'r')

# %%
plt.hist()

# %%
m = np.array(hfile1['test/num_un_strings/data'])
mask = np.where(m == 2)[0]

# %%
(m == 2).sum() / (m != 2).sum()
# Out:
# 0.30680801958994974

# %%
 hfile1['test/ev_starts/data'][:10]
# Out:
# array([  0,  16,  24,  36,  47,  75, 103, 111, 120, 128])

# %%
 hfile2['test/ev_starts/data'][:10]
# Out:
# array([  0,  16,  25,  34,  42,  64,  82,  91, 100, 127])

# %%
hfile1['test/num_un_strings/data'].shape, hfile2['test/num_un_strings/data'].shape
# Out:
# ((1429154,), (444085,))

# %%
data = np.array(hfile2['test/num_un_strings/data'])
data.min()
# Out:
# 3

# %%
hfile2['test'].keys(), hfile1['test'].keys()
# Out:
# (<KeysViewHDF5 ['data', 'ev_ids', 'ev_starts', 'labels', 'num_un_strings', 'prime_prty', 't_res']>,
#  <KeysViewHDF5 ['channels', 'data', 'ev_ids', 'ev_starts', 'labels', 'muons_prty', 'num_un_strings', 'prime_prty', 't_res']>)

# %%
hfile1['test/prime_prty/data'].shape, hfile2['test/prime_prty/data'].shape,
# Out:
# ((1429154, 6), (444085, 6))

# %%
1429154 // 444085
# Out:
# 3

# %%
37561563 / 35699405
# Out:
# 1.0521621578847042

# %%
hfile1['train/ev_starts/data'].shape, hfile2['train/ev_starts/data'].shape,
# Out:
# ((9467116,), (2214924,))

# %%
9467116 // 2214924
# Out:
# 4

# %%
hfile1['test/ev_starts/data'][-1], hfile2['test/ev_starts/data'][-1]
# Out:
# (37561563, 335504)

# %%
# Out:
# 28

# %%
hfile['test'].keys()
# Out:
# <KeysViewHDF5 ['channels', 'data', 'ev_ids', 'ev_starts', 'labels', 'muons_prty', 'num_un_strings', 'prime_prty', 't_res']>

# %%
hfile_old['test'].keys()
# Out:
# <KeysViewHDF5 ['data', 'ev_chars', 'ev_ids', 'labels_full', 'labels_num_mu', 'labels_one_mu', 'labels_particle', 'labels_signal_noise', 'labels_track_type', 'mask']>

# %%
hfile_old['test/data'].shape, hfile['test/data/data'].shape
# Out:
# ((133807, 35, 5), (37561563, 5))

# %%
from tqdm import tqdm

# %%
data = set(frozenset(k) for k in tqdm(hfile_old['test/labels_particle']))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 133807/133807 [00:01<00:00, 108385.93it/s]

# %%
data

# %%
# print(*plt.style.available, sep='\n')

# %%
plt.style.use('seaborn-v0_8-paper')

# %%
# sns.color_palette('husl', 9)

# %%
sns.color_palette('pastel', 6)
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019)]

# %%
# colors = list(sns.color_palette('pastel', 9).as_hex())
colors = list(sns.color_palette("Paired"))

# %%
# !mkdir /home/plotnikovgp/baikal/Baikal-ML/pytorch_training/notebooks/plots
# Out:
# mkdir: cannot create directory ‘/home/plotnikovgp/baikal/Baikal-ML/pytorch_training/notebooks/plots’: File exists

# %%
import numpy as np
import h5py as h5
import matplotlib.pyplot as plt
import seaborn as sns


data_file = "/home/plotnikovgp/baikal/data/baikal_multi_0324_flat_treck-cascade_h8_s2_pureMC_normed.h5"
# data_file = "/home/plotnikovgp/baikal/data/baikal_mc2020_multi_split_0924_MChits-8-2_normed.h5"
data_file_old = "/home/plotnikovgp/baikal/data/exp.h5"
hfile = h5.File(data_file, "r")
hfile_old = h5.File(data_file_old, "r")

# %%
len(hfile_old['exp/raw/data/'])
# Out:
# 26

# %%
keys = [str(k) for k in hfile_old['exp/raw/data'].keys()]

for i in range(len(hfile_old['exp/raw/data/'])):
    print(f'exp/raw/data/{keys[i]}')
    t = hfile_old[f'exp/raw/data/{keys[i]}/data'][:, 1]
    plt.hist(t)
    if i > 5:
        break
# Out:
# exp/raw/data/part_s2020_c01_r0027
# exp/raw/data/part_s2020_c01_r0116
# exp/raw/data/part_s2020_c01_r0188
# exp/raw/data/part_s2020_c02_r0015
# exp/raw/data/part_s2020_c02_r0149
# exp/raw/data/part_s2020_c02_r0206
# exp/raw/data/part_s2020_c02_r0357

# %%
len(hfile_old['test/data/data'][:, 1]), len(hfil['test/data/data'][:, 1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 len(hfile_old['test/data/data'][:, 1]), len(hfile['test/data/data'][:, 1])
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/tmp/ENTER/lib/python3.11/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:190, in h5py.h5o.open()
#
# KeyError: 'Unable to open object (component not found)'

# %%
time = np.array(hfile["test/data/data"][:, 1])
time_old = np.array(hfile_old['test/data/data'][:, 1])

# theta = np.array(hfile["test/prime_prty/data"][:, 0])
# phi = np.array(hfile["test/prime_prty/data"][:, 1])

# theta_old = np.array(hfile_old['test/ev_chars'][:, 0])
# phi_old = np.array(hfile_old['test/ev_chars'][:, 1])


num_strings = np.array(hfile['test']['num_un_strings/data'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 time = np.array(hfile["test/data/data"][:, 1])
#       2 time_old = np.array(hfile_old['test/data/data'][:, 1]) * 10
#       4 # theta = np.array(hfile["test/prime_prty/data"][:, 0])
#       5 # phi = np.array(hfile["test/prime_prty/data"][:, 1])
#       6
#       7 # theta_old = np.array(hfile_old['test/ev_chars'][:, 0])
#       8 # phi_old = np.array(hfile_old['test/ev_chars'][:, 1])
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/tmp/ENTER/lib/python3.11/site-packages/h5py/_hl/dataset.py:758, in Dataset.__getitem__(self, args, new_dtype)
#     756 if self._fast_read_ok and (new_dtype is None):
#     757     try:
# --> 758         return self._fast_reader.read(args)
#     759     except TypeError:
#     760         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %%
num_strings.shape
# Out:
# (1429154,)

# %%
bins = 50

fig, axs = plt.subplots(figsize=(12, 10), nrows=2, ncols=2)

theta_color = colors[1]
phi_color = colors[0]

axs[0, 0].hist(theta[energy > 1e5], bins=bins, label="theta new", color=theta_color, density=False)
axs[0, 1].hist(phi, bins=bins, label="phi new", color=phi_color, density=False)
axs[1, 0].hist(theta_old, bins=bins, label="theta old", color=theta_color, density=False)
axs[1, 1].hist(phi_old, bins=bins, label="phi old", color=phi_color, density=False)

titles = ["Theta New Distribution", "Phi New Distribution", "Theta Old Distribution", "Phi Old Distribution"]
for ax, title in zip(axs.flat, titles):
    ax.set_title(title)
    ax.set_xlabel('Degree (deg)')
    ax.set_ylabel('Count')
    ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('/home/plotnikovgp/baikal/Baikal-ML/pytorch_training/notebooks/plots/angle_debug_old_vs_new_angles_distr.png')
plt.show()

# %%
theta.shape, energy.shape
theta_ = theta[::10]
energy_ = energy[::10]

# %%
theta_.shape, theta_old.shape
# Out:
# ((142916,), (133807,))

# %%
fig, axs = plt.subplots(figsize=(9, 11), nrows=2)

s = 1.0
axs[0].scatter(theta_, energy_, label='new', s=s)
axs[0].set(ylabel="E, GeV", xlabel="theta, deg", )
axs[1].scatter(theta_old, energy_old, label='old', s=s)
axs[1].set(ylabel="E, GeV", xlabel="theta, deg")
for ax in axs:
    ax.legend()
plt.show()
pass

# %%
fig, ax = plt.subplots(figsize=(10, 7))

ax.scatter(theta_old, energy_old)
ax.set(ylabel="E, GeV", xlabel="theta, deg")
# Out:
# [Text(0, 0.5, 'E, GeV'), Text(0.5, 0, 'theta, deg')]

# %%
fig, (ax1, ax2) = plt.subplots(figsize=[10, 10], nrows=2)
thr = 1e5
ax1.hist(energy[energy < thr], label="energy new", bins=50, density=False)
ax2.hist(energy_old[energy_old < thr], label="energy old", bins=50, density=False, color='g')
ax1.set(xlabel='GeV', ylabel='count')
ax2.set(xlabel='GeV', ylabel='count')
ax1.legend()
ax2.legend()

# %%
energy_old.shape
# Out:
# (133807,)

# %%
fig, (ax1, ax2) = plt.subplots(figsize=[10, 10], nrows=2)
thr = 1e5
ax1.hist(energy[energy < thr], label="energy new", bins=50, density=False)
ax2.hist(energy_old[energy_old < thr], label="energy old", bins=50, density=False, color='g')
ax1.set(xlabel='GeV', ylabel='count')
ax2.set(xlabel='GeV', ylabel='count')
ax1.legend()
ax2.legend()

# %%
hfile['test'].keys()
# Out:
# <KeysViewHDF5 ['channels', 'data', 'ev_ids', 'ev_starts', 'labels', 'muons_prty', 'num_un_strings', 'prime_prty', 't_res']>

# %%
data = hfile['test']['num_un_strings/data']

# %%
# data[:100]

# %%
# energy = np.array(hfile["test/prime_prty/data"][:, 2])

# %%
energy.mean(), energy.std() # ГэВ
# Out:
# (366804.25, 1097577.9)

# %%
energy_old.mean(), energy_old.std() # ГэВ
# Out:
# (1269.0048, 4549.8247)

# %%
data = np.array(hfile["train/prime_prty/data/ev_starts/data"][:10000])
data.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 data = np.array(hfile["train/prime_prty/data/ev_starts/data"][:10000])
#       2 data.shape
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/tmp/ENTER/lib/python3.11/site-packages/h5py/_hl/group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:190, in h5py.h5o.open()
#
# KeyError: 'Unable to open object (message type not found)'

# %%
i = 1
hfile["train/ev_starts/data"][i: i + 2]
# Out:
# array([59, 68])

# %%
event_sizes = []
for i in range(10000):
    start, end = hfile["train/ev_starts/data"][i: i + 2]
    event_sizes.append(end - start)

# %%
max(event_sizes)
# Out:
# 881

# %%
min(event_sizes)
# Out:
# 8

# %%
np.mean(event_sizes)
# Out:
# 26.3768

# %%
event_sizes = np.array(event_sizes)
event_sizes = event_sizes[event_sizes < 50]

# %%
fig, ax = plt.subplots(figsize=[10, 7])
# energy = np.array(energy[)
data = np.array(data)
sns.histplot(data)
# ax.set_xticks(np.arange(0, 180, 10))
ax.set(xlabel="energy", ylabel="count")
pass

# %%
fig, ax = plt.subplots(figsize=[10, 7])
thetas = data[:, 0]
sns.histplot(thetas, bins=60)
# ax.set_xticks(np.arange(0, 180, 10))
ax.set(xlabel="theta, degrees", ylabel="count")
pass

# %%
fig, ax = plt.subplots(figsize=[10, 7])
sns.histplot(data[:, 1], bins=60)
ax.set_xticks(np.arange(0, 360, 20))
ax.set(xlabel="phi, degrees", ylabel="count")
pass

# %%
thetha, phi = self.hfile[self.split_type + "/prime_prty/data"][idx][:2]

# %%
import torch
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from torch.nn.functional import cosine_similarity, normalize
from torch_geometric.nn import global_mean_pool

LEGEND_SIZE = 20
TITLE_SIZE = 25
LABEL_SIZE = 20
TICKS_SIZE = 20

plt.rcParams.update({'font.size': 20})
METRICS = ['polar_res', 'polar_r2', 'azimut_res', 'direction_res']
 
#################################    outp_to_res_and_angles       ####################
def outp_to_res_and_angles(predict, true):
    p_true = torch.acos(true[:,-1]) * 180 / np.pi
    # нормализую 
    v_pred = normalize(predict.detach()) if predict.shape[1] <= 3 else normalize(predict[:,:-1].detach())
    p_predict = torch.acos(v_pred[:,2]) * 180 / np.pi
      
    
    
    outp_size = true.shape[1]
    # only polar prediction
    if outp_size == 2: 
        return None, [p_predict, p_true]
    
    # direction prediction (mb with uncertainty)
    else:           
        az_true = torch.acos(true[:,0] / true[:,:2].norm(dim=1)) * 180 / np.pi
        sin_sign = torch.sign(true[:,1])
        az_true = torch.where(sin_sign > 0, az_true, 360 - az_true)

        az_predict = torch.acos(v_pred[:,0] / v_pred[:,:2].norm(dim=1)) * 180 / np.pi
        sin_sign = torch.sign(v_pred[:,1])
        az_predict = torch.where(sin_sign > 0, az_predict, 360 - az_predict)
        
        resolution = (v_pred * true).sum(axis = 1).clamp(max = 1.).acos() * 180 / np.pi
        return resolution, [p_predict, p_true, az_predict, az_true]


#########################   loss_plot    ############################

def loss_plot(train_loss, test_loss, path = None, show = True ):
    plt.figure(figsize=(9,6))
    plt.plot(np.arange(len(test_loss)), test_loss, label='test', linewidth=2)
    plt.plot(np.arange(len(train_loss)), train_loss, label='train', linewidth=2)
    
    plt.title('Loss_plot', fontsize = TITLE_SIZE)
    plt.xlabel('Epochs', fontsize = LABEL_SIZE)
    plt.ylabel('Loss', fontsize = LABEL_SIZE)
    plt.legend(fontsize = LEGEND_SIZE)
    
    plt.savefig(path)   
    if not show:
        plt.close()
    else:
        plt.show() 

###########################   resolution_hist  ########################

def resolution_hist(resolution, x_min = 0.0, x_max = 15, title = ''):
    title = title.title()
    med, sigm2 = np.quantile(resolution, q = 0.5), np.quantile(resolution, q = 0.68)
 
    hist = plt.hist(resolution, bins = 300, histtype= 'step', density = True)   
    height = max(hist[0]) #[0]    
    plt.bar(med, height, width = x_max /60, align='center', color = "red",
            label = f'Res_50% = {round(med, 2)}')   
    plt.bar(sigm2, height, width = x_max /60, align='center', color = "orange",
            label = f'Res_68% = {round(sigm2, 2)}')
    
    plt.xlabel(f"Resolution", fontsize= LABEL_SIZE)
    plt.xlim(left = x_min, right=x_max) 
    plt.title(f"{title} Resolution Distribution", fontsize= TITLE_SIZE)
    plt.legend(fontsize = LEGEND_SIZE)   
    return med

###################################  angle_hist   ############################## 

def angle_hist(true, predict, title = ''):
    title = title.title()
    plt.hist(true, bins = 100, alpha = 0.2, density = True,
             label = f"True {title}")
    plt.hist(predict, bins = 100, histtype= 'step', density = True,
             label = f"Predicted {title}")
    plt.xlabel(f"{title} Angle", fontsize = LABEL_SIZE)
    plt.title(f"{title} Angle Distribution", fontsize = TITLE_SIZE)
    plt.legend(fontsize = LEGEND_SIZE)

######################  scatter_plot     ##########################     
    
def scatter_plot(true, predict, title = '', r2 = None):
    title = title.title()
    plt.scatter(true, predict, s = 0.1)
    plt.xlabel(f'True {title}', fontsize = LABEL_SIZE)
    plt.ylabel(f'Predicted {title}', fontsize = LABEL_SIZE)
    if r2 != None:
        plt.title(f'{title} Scatter Plot \n R2 = {round(r2,3)}', fontsize = TITLE_SIZE) 
        return r2
    else:
        plt.title(f'{title} Scatter Plot', fontsize = TITLE_SIZE)     
        
#############################   record_plots     ################################

def metrics_plots(record, path = None, show = False):
    names = list(record.keys())
    n = len(names)
    plt.figure(figsize=(18,6 * n // 2))
    for i in range(n):
        plt.subplot(n // 2, 2, i + 1)
        plt.plot(record[names[i]])
        plt.title(names[i], fontsize = TITLE_SIZE)
        plt.ylabel(names[i], fontsize = LABEL_SIZE)
        plt.xlabel('Epochs', fontsize = LABEL_SIZE)
    plt.legend(fontsize = LEGEND_SIZE)
    
    if path is not None:
        plt.savefig(path)   
    if not show:
        plt.close()
    else:
        plt.show() 

##################################    make_record_df    ###############################

def make_record_df(records, folds, exp_path = None):
    cvs = pd.Series([f'CV{i}' for i in range(folds)])
    df = pd.DataFrame.from_dict(records).set_index(cvs)

    mean, std = df.mean().values, df.std().values
    df_add = pd.DataFrame([mean, std/mean*100], columns = list(records.keys()), index=['mean', 'std/mean*%'])
    df = df.append(df_add).round(2)
    if exp_path is not None:
        df.to_csv(f'{exp_path}/cv_metrics.csv', sep='\t')
    return df   
    
###########################  metrics_by_angles  #############################
    
def metrics_by_angles(pol_true_list, pol_res_list, az_res_list, resolution_list,
                      bin_size = 10, angle = 4, path = None, show = False):

    max_bin = 90 // bin_size
    bins = (np.arange(max_bin) + 0.5) * bin_size
    inds = pol_true_list // bin_size
    
    if angle == 2:
        plot =  {'med': [],'sigm2': []}   
        for i in range(max_bin): # don't take into account  last bin, because it starts from 90
            ids = np.where(inds == i)    
            pol_res = pol_res_list[ids] 
            plot['med'].append(  np.quantile(pol_res, q = 0.5 ))
            plot['sigm2'].append(np.quantile(pol_res, q = 0.68)) 

        plt.figure(figsize = (16,7))

        plt.plot(bins, plot['med'], label = 'med', color = 'blue')
        plt.plot(bins, plot['sigm2'], label = 'sigm2', color = 'orange')
        print(plot['med'])
        _title = "Polar"
        plt.legend(fontsize = LEGEND_SIZE)
        plt.title(_title, fontsize = TITLE_SIZE)
        plt.xlabel('Angle bins', fontsize = LABEL_SIZE)
        plt.ylabel('Resolutions', fontsize = LABEL_SIZE)
        plt.xticks(np.arange(0,95,5), fontsize = TICKS_SIZE)

    if angle == 4:
        keys = ['Polar', 'Azimut', 'Direction']
        plot = { name : {'med': [],'sigm2': []} for name in keys }   
        for i in range(max_bin): # don't take into account  last bin, because it starts from 90
            ids = np.where(inds == i)
            res_s = [ pol_res_list[ids], az_res_list[ids], resolution_list[ids] ] 
            for k, arr in zip(keys, res_s):
                plot[k]['med'].append(  np.quantile(arr, q = 0.5 ))
                plot[k]['sigm2'].append(np.quantile(arr, q = 0.68))
        plt.figure(figsize = (36,12))
        for i, k in enumerate(keys):
            plt.subplot(1,3,i + 1)

            plt.plot(bins, plot[k]['med'], label = 'med', color = 'blue')
            plt.plot(bins, plot[k]['sigm2'], label = 'sigm2', color = 'orange')
            _title = f"{k} \n med:{[round(v,2) for v in plot[k]['med']]}\n res68%:{[round(v,2) for v in plot[k]['sigm2']]}"
            plt.legend(fontsize = LEGEND_SIZE)
            print(k, plot[k]['med'])
            plt.title(_title, fontsize = 18) #\n {[round(v,2) for v in plot[k]['med'] ]}
            plt.xlabel('Angle bins', fontsize = LABEL_SIZE)
            plt.ylabel('Resolutions', fontsize = LABEL_SIZE)
            plt.xticks(np.arange(0,95,5), fontsize = TICKS_SIZE)
            plt.grid()
    if path != None:
        plt.savefig(path)  
    if not show:
        plt.close()
    else:
        plt.show()      
    
###############################   Model_Info     #####################################
def Model_Info(model, loader, regime = "test",
               bin_size = 10, mode = 'CNN',
               path_record = None, path_m_by_angle = None,
               show_distr_by_polar_angle = True,show = True
               ):
    record = {}
    _device = next(model.parameters()).device
    pol_pred_list, pol_true_list = torch.tensor([]), torch.tensor([]), 
    az_pred_list, az_true_list = torch.tensor([]), torch.tensor([])
    pol_res_list, az_res_list = torch.tensor([]), torch.tensor([])
    resolution_list = torch.tensor([])
    
    with torch.no_grad():       
        if mode == 'CNN': ############# CNN ###############################
            for x_batch, y_batch in loader:
                predict = model(x_batch.to(_device).float()).detach().cpu()
                
                resolution, angles = outp_to_res_and_angles(predict, y_batch)  

                p_predict, p_true = angles[0].squeeze(), angles[1].squeeze()
                p_res = (p_predict - p_true).abs()

                pol_res_list = torch.cat((pol_res_list, p_res), axis = 0)         
                pol_true_list = torch.cat((pol_true_list, p_true), axis = 0)
                pol_pred_list = torch.cat((pol_pred_list, p_predict), axis = 0)
                
                if len(angles) == 4:           
                    az_predict, az_true = angles[2].squeeze(), angles[3].squeeze()
                    az_res = (az_predict - az_true).abs()
                    az_res = torch.where(az_res < 180, az_res, 360 - az_res)

                    az_res_list = torch.cat((az_res_list, az_res), axis = 0)  
                    az_true_list = torch.cat((az_true_list, az_true), axis = 0)
                    az_pred_list = torch.cat((az_pred_list, az_predict), axis = 0)
                    resolution_list = torch.cat((resolution_list, resolution), axis = 0)           
        elif mode == 'GNN': ############# GNN ###############################
            for data in loader:
                data = data.to(_device)
                outp = model(data).detach().cpu()  
                
                y_batch = data.y_polar if outp.shape[1] == 2 else data.direction 
                y_batch = y_batch.squeeze().cpu()
      
                resolution, angles = outp_to_res_and_angles(outp, y_batch) 

                p_predict, p_true = angles[0].squeeze(), angles[1].squeeze()
                p_res = (p_predict - p_true).abs()

                pol_res_list = torch.cat((pol_res_list, p_res), axis = 0)         
                pol_true_list = torch.cat((pol_true_list, p_true), axis = 0)
                pol_pred_list = torch.cat((pol_pred_list, p_predict), axis = 0)
                
                if len(angles) == 4:           
                    az_predict, az_true = angles[2].squeeze(), angles[3].squeeze()
                    az_res = (az_predict - az_true).abs()
                    az_res = torch.where(az_res < 180, az_res, 360 - az_res)

                    az_res_list = torch.cat((az_res_list, az_res), axis = 0)  
                    az_true_list = torch.cat((az_true_list, az_true), axis = 0)
                    az_pred_list = torch.cat((az_pred_list, az_predict), axis = 0)
                    resolution_list = torch.cat((resolution_list, resolution), axis = 0)                    
        else:
            print("Emmmm.... What?")
        
    resolution_list = resolution_list.numpy()
    pol_res_list, az_res_list = pol_res_list.numpy(), az_res_list.numpy()   
    az_true_list, az_pred_list = az_true_list.numpy(), az_pred_list.numpy()      
    pol_true_list, pol_pred_list = pol_true_list.numpy(), pol_pred_list.numpy()
    print(az_true_list.min(), az_true_list.max())
    print("MAE azimut:", np.mean(np.abs(az_true_list - az_pred_list)))
    print(pol_true_list.min(), pol_true_list.max())
    print("MAE pol:", np.mean(np.abs(pol_true_list - pol_pred_list)))
    # drawing
    rows = 1 if az_pred_list.shape[0] == 0 else 3   
    plt.figure(figsize = (24, 8 * rows))   
    # polar  resolution
    plt.subplot(rows, 3, 1)
    polar_med = resolution_hist(resolution = pol_res_list, title = f'{regime} polar', x_max = 15)
    record['polar_res'] = polar_med
    # polar scatter
    plt.subplot(rows, 3, 2)
    polar_r2 =scatter_plot(true = pol_true_list, predict = pol_pred_list, title = f'{regime} polar',
                 r2 = r2_score(pol_true_list, pol_pred_list))
    record['polar_r2'] = polar_r2
    # polar distribution
    plt.subplot(rows, 3, 3)
    angle_hist(true = pol_true_list, predict = pol_pred_list, title = f'{regime} polar')
    
    if rows == 3: 
        # azimut  resolution
        plt.subplot(rows, 3, 4)
        azimut_res = resolution_hist(resolution = az_res_list, title = f'{regime} azimut', x_max = 45)
        record['azimut_res'] = azimut_res
        # azimut scatter
        plt.subplot(rows, 3, 5)
        scatter_plot(true = az_true_list, predict = az_pred_list, title = f'{regime} azimut')
        # azimut distribution
        plt.subplot(rows, 3, 6)
        angle_hist(true = az_true_list, predict = az_pred_list, title = f'{regime} azimut')
        # direction  resolution
        plt.subplot(rows, 3, 8)
        direction_res = resolution_hist(resolution = resolution_list, title = f'{regime} direction', x_max = 15)
        record['direction_res'] = direction_res
        
    if path_record != None:
        plt.savefig(path_record)
    ############         Metrics for  certain polar angle values   ###################
    if show_distr_by_polar_angle:
        metrics_by_angles(pol_true_list, pol_res_list, az_res_list, resolution_list,
                          bin_size = bin_size, angle = rows + 1, path = path_m_by_angle, show = show)        
    ##################################################################################    
    if not show:
        plt.close()
    else:
        plt.show()  
    return record
 
    
###########################################                  test_resolution           ##############    
def test_err_and_res(model, loader, mode = 'GNN'):
    error = 0
    _device = next(model.parameters()).device
    resolution_list = torch.tensor([])
    
    with torch.no_grad():       
        if mode == 'CNN': ############# CNN ###############################
            for x_batch, y_batch in loader:
                predict = model(x_batch.to(_device).float()).detach().cpu()     
                resolution, angles = outp_to_res_and_angles(predict, y_batch)          
                error += criterion(outp, y_batch).item() 
                if len(angles) == 4:           
                    resolution_list = torch.cat((resolution_list, resolution), axis = 0)
                    
                else:
                    p_predict, p_true = angles[0].squeeze(), angles[1].squeeze()
                    p_res = (p_predict - p_true).abs()
                    resolution_list = torch.cat((resolution_list, p_res), axis = 0)  
                    
        elif mode == 'GNN': ############# GNN ###############################
            for data in loader:
                data = data.to(_device)
                outp = model(data).detach().cpu()  
                
                if outp.shape[1] == 2:
                    y_batch = data.y_polar.squeeze().cpu()                    
                elif outp.shape[1] == 3:
                    y_batch = data.direction.squeeze().cpu()
                    
                resolution, angles = outp_to_res_and_angles(outp, y_batch) 
                error += criterion(outp, y_batch).item()  
                if len(angles) == 4:           
                    resolution_list = torch.cat((resolution_list, resolution), axis = 0)  
                    
                else:
                    p_predict, p_true = angles[0].squeeze(), angles[1].squeeze()
                    p_res = (p_predict - p_true).abs()
                    resolution_list = torch.cat((resolution_list, p_res), axis = 0)
        else:
            print("Emmmm.... What?")
    res = np.quantile(resolution_list.numpy(), q = 0.5)
    return res, error / len(loader)
    
'''
def GNN_Info(model, loader, regime = "train"):
    _device = next(model.parameters()).device
    pol_pred_list, pol_true_list, res_list = torch.tensor([]), torch.tensor([]), torch.tensor([])
    #angle_list = torch.tensor([])   
    for data in loader:
        #polar = torch.FloatTensor([hf[regime + '/ev_chars'][ind,0] * (np.pi) / 180])[None,:]
        #y_polar = torch.cat((torch.sin(polar), torch.cos(polar)), axis=1)
        v_pred = normalize(model( data.to(_device) ) ).cpu()
        p_pred = torch.acos(v_pred[:,-1]) 
        p_true = data.polar.squeeze().cpu()   
        pol_res = torch.abs(p_true - p_pred)
        res_list = torch.cat((res_list, pol_res), axis = 0)
        pol_true_list = torch.cat((pol_true_list, p_pred), axis = 0)
        pol_pred_list = torch.cat((pol_pred_list, p_true), axis = 0)
        
    res_list = (res_list / np.pi * 180).detach().numpy()
    #angle_list = (angle_list / np.pi * 180).detach().numpy()
    pol_pred_list = (pol_pred_list / np.pi * 180).detach().numpy()
    pol_true_list = (pol_true_list / np.pi * 180).detach().numpy()
'''

# %%
import torch
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from torch.nn.functional import cosine_similarity, normalize
from torch_geometric.nn import global_mean_pool

LEGEND_SIZE = 20
TITLE_SIZE = 25
LABEL_SIZE = 20
TICKS_SIZE = 20

plt.rcParams.update({'font.size': 20})
METRICS = ['polar_res', 'polar_r2', 'azimut_res', 'direction_res']
 
#################################    outp_to_res_and_angles       ####################
def outp_to_res_and_angles(predict, true):
    p_true = torch.acos(true[:,-1]) * 180 / np.pi
    # нормализую 
    v_pred = normalize(predict.detach()) if predict.shape[1] <= 3 else normalize(predict[:,:-1].detach())
    p_predict = torch.acos(v_pred[:,2]) * 180 / np.pi
      
    
    
    outp_size = true.shape[1]
    # only polar prediction
    if outp_size == 2: 
        return None, [p_predict, p_true]
    
    # direction prediction (mb with uncertainty)
    else:           
        az_true = torch.acos(true[:,0] / true[:,:2].norm(dim=1)) * 180 / np.pi
        sin_sign = torch.sign(true[:,1])
        az_true = torch.where(sin_sign > 0, az_true, 360 - az_true)

        az_predict = torch.acos(v_pred[:,0] / v_pred[:,:2].norm(dim=1)) * 180 / np.pi
        sin_sign = torch.sign(v_pred[:,1])
        az_predict = torch.where(sin_sign > 0, az_predict, 360 - az_predict)
        
        resolution = (v_pred * true).sum(axis = 1).clamp(max = 1.).acos() * 180 / np.pi
        return resolution, [p_predict, p_true, az_predict, az_true]


#########################   loss_plot    ############################

def loss_plot(train_loss, test_loss, path = None, show = True ):
    plt.figure(figsize=(9,6))
    plt.plot(np.arange(len(test_loss)), test_loss, label='test', linewidth=2)
    plt.plot(np.arange(len(train_loss)), train_loss, label='train', linewidth=2)
    
    plt.title('Loss_plot', fontsize = TITLE_SIZE)
    plt.xlabel('Epochs', fontsize = LABEL_SIZE)
    plt.ylabel('Loss', fontsize = LABEL_SIZE)
    plt.legend(fontsize = LEGEND_SIZE)
    
    plt.savefig(path)   
    if not show:
        plt.close()
    else:
        plt.show() 

###########################   resolution_hist  ########################

def resolution_hist(resolution, x_min = 0.0, x_max = 15, title = ''):
    title = title.title()
    med, sigm2 = np.quantile(resolution, q = 0.5), np.quantile(resolution, q = 0.68)
 
    hist = plt.hist(resolution, bins = 300, histtype= 'step', density = True)   
    height = max(hist[0]) #[0]    
    plt.bar(med, height, width = x_max /60, align='center', color = "red",
            label = f'Res_50% = {round(med, 2)}')   
    plt.bar(sigm2, height, width = x_max /60, align='center', color = "orange",
            label = f'Res_68% = {round(sigm2, 2)}')
    
    plt.xlabel(f"Resolution", fontsize= LABEL_SIZE)
    plt.xlim(left = x_min, right=x_max) 
    plt.title(f"{title} Resolution Distribution", fontsize= TITLE_SIZE)
    plt.legend(fontsize = LEGEND_SIZE)   
    return med

###################################  angle_hist   ############################## 

def angle_hist(true, predict, title = ''):
    title = title.title()
    plt.hist(true, bins = 100, alpha = 0.2, density = True,
             label = f"True {title}")
    plt.hist(predict, bins = 100, histtype= 'step', density = True,
             label = f"Predicted {title}")
    plt.xlabel(f"{title} Angle", fontsize = LABEL_SIZE)
    plt.title(f"{title} Angle Distribution", fontsize = TITLE_SIZE)
    plt.legend(fontsize = LEGEND_SIZE)

######################  scatter_plot     ##########################     
    
def scatter_plot(true, predict, title = '', r2 = None):
    title = title.title()
    plt.scatter(true, predict, s = 0.1)
    plt.xlabel(f'True {title}', fontsize = LABEL_SIZE)
    plt.ylabel(f'Predicted {title}', fontsize = LABEL_SIZE)
    if r2 != None:
        plt.title(f'{title} Scatter Plot \n R2 = {round(r2,3)}', fontsize = TITLE_SIZE) 
        return r2
    else:
        plt.title(f'{title} Scatter Plot', fontsize = TITLE_SIZE)     
        
#############################   record_plots     ################################

def metrics_plots(record, path = None, show = False):
    names = list(record.keys())
    n = len(names)
    plt.figure(figsize=(18,6 * n // 2))
    for i in range(n):
        plt.subplot(n // 2, 2, i + 1)
        plt.plot(record[names[i]])
        plt.title(names[i], fontsize = TITLE_SIZE)
        plt.ylabel(names[i], fontsize = LABEL_SIZE)
        plt.xlabel('Epochs', fontsize = LABEL_SIZE)
    plt.legend(fontsize = LEGEND_SIZE)
    
    if path is not None:
        plt.savefig(path)   
    if not show:
        plt.close()
    else:
        plt.show() 

##################################    make_record_df    ###############################

def make_record_df(records, folds, exp_path = None):
    cvs = pd.Series([f'CV{i}' for i in range(folds)])
    df = pd.DataFrame.from_dict(records).set_index(cvs)

    mean, std = df.mean().values, df.std().values
    df_add = pd.DataFrame([mean, std/mean*100], columns = list(records.keys()), index=['mean', 'std/mean*%'])
    df = df.append(df_add).round(2)
    if exp_path is not None:
        df.to_csv(f'{exp_path}/cv_metrics.csv', sep='\t')
    return df   
    
###########################  metrics_by_angles  #############################
    
def metrics_by_angles(pol_true_list, pol_res_list, az_res_list, resolution_list,
                      bin_size = 10, angle = 4, path = None, show = False):

    max_bin = 90 // bin_size
    bins = (np.arange(max_bin) + 0.5) * bin_size
    inds = pol_true_list // bin_size
    
    if angle == 2:
        plot =  {'med': [],'sigm2': []}   
        for i in range(max_bin): # don't take into account  last bin, because it starts from 90
            ids = np.where(inds == i)    
            pol_res = pol_res_list[ids] 
            plot['med'].append(  np.quantile(pol_res, q = 0.5 ))
            plot['sigm2'].append(np.quantile(pol_res, q = 0.68)) 

        plt.figure(figsize = (16,7))

        plt.plot(bins, plot['med'], label = 'med', color = 'blue')
        plt.plot(bins, plot['sigm2'], label = 'sigm2', color = 'orange')
        print(plot['med'])
        _title = "Polar"
        plt.legend(fontsize = LEGEND_SIZE)
        plt.title(_title, fontsize = TITLE_SIZE)
        plt.xlabel('Angle bins', fontsize = LABEL_SIZE)
        plt.ylabel('Resolutions', fontsize = LABEL_SIZE)
        plt.xticks(np.arange(0,95,5), fontsize = TICKS_SIZE)

    if angle == 4:
        keys = ['Polar', 'Azimut', 'Direction']
        plot = { name : {'med': [],'sigm2': []} for name in keys }   
        for i in range(max_bin): # don't take into account  last bin, because it starts from 90
            ids = np.where(inds == i)
            res_s = [ pol_res_list[ids], az_res_list[ids], resolution_list[ids] ] 
            for k, arr in zip(keys, res_s):
                plot[k]['med'].append(  np.quantile(arr, q = 0.5 ))
                plot[k]['sigm2'].append(np.quantile(arr, q = 0.68))
        plt.figure(figsize = (36,12))
        for i, k in enumerate(keys):
            plt.subplot(1,3,i + 1)

            plt.plot(bins, plot[k]['med'], label = 'med', color = 'blue')
            plt.plot(bins, plot[k]['sigm2'], label = 'sigm2', color = 'orange')
            _title = f"{k} \n med:{[round(v,2) for v in plot[k]['med']]}\n res68%:{[round(v,2) for v in plot[k]['sigm2']]}"
            plt.legend(fontsize = LEGEND_SIZE)
            print(k, plot[k]['med'])
            plt.title(_title, fontsize = 18) #\n {[round(v,2) for v in plot[k]['med'] ]}
            plt.xlabel('Angle bins', fontsize = LABEL_SIZE)
            plt.ylabel('Resolutions', fontsize = LABEL_SIZE)
            plt.xticks(np.arange(0,95,5), fontsize = TICKS_SIZE)
            plt.grid()
    if path != None:
        plt.savefig(path)  
    if not show:
        plt.close()
    else:
        plt.show()      
    
###############################   Model_Info     #####################################
def Model_Info(model, loader, regime = "test",
               bin_size = 10, mode = 'CNN',
               path_record = None, path_m_by_angle = None,
               show_distr_by_polar_angle = True,show = True
               ):
    record = {}
    _device = next(model.parameters()).device
    pol_pred_list, pol_true_list = torch.tensor([]), torch.tensor([]), 
    az_pred_list, az_true_list = torch.tensor([]), torch.tensor([])
    pol_res_list, az_res_list = torch.tensor([]), torch.tensor([])
    resolution_list = torch.tensor([])
    
    with torch.no_grad():       
        if mode == 'CNN': ############# CNN ###############################
            for x_batch, y_batch in loader:
                predict = model(x_batch.to(_device).float()).detach().cpu()
                
                resolution, angles = outp_to_res_and_angles(predict, y_batch)  

                p_predict, p_true = angles[0].squeeze(), angles[1].squeeze()
                p_res = (p_predict - p_true).abs()

                pol_res_list = torch.cat((pol_res_list, p_res), axis = 0)         
                pol_true_list = torch.cat((pol_true_list, p_true), axis = 0)
                pol_pred_list = torch.cat((pol_pred_list, p_predict), axis = 0)
                
                if len(angles) == 4:           
                    az_predict, az_true = angles[2].squeeze(), angles[3].squeeze()
                    az_res = (az_predict - az_true).abs()
                    az_res = torch.where(az_res < 180, az_res, 360 - az_res)

                    az_res_list = torch.cat((az_res_list, az_res), axis = 0)  
                    az_true_list = torch.cat((az_true_list, az_true), axis = 0)
                    az_pred_list = torch.cat((az_pred_list, az_predict), axis = 0)
                    resolution_list = torch.cat((resolution_list, resolution), axis = 0)           
        elif mode == 'GNN': ############# GNN ###############################
            for data in loader:
                data = data.to(_device)
                outp = model(data).detach().cpu()  
                
                y_batch = data.y_polar if outp.shape[1] == 2 else data.direction 
                y_batch = y_batch.squeeze().cpu()
      
                resolution, angles = outp_to_res_and_angles(outp, y_batch) 

                p_predict, p_true = angles[0].squeeze(), angles[1].squeeze()
                p_res = (p_predict - p_true).abs()

                pol_res_list = torch.cat((pol_res_list, p_res), axis = 0)         
                pol_true_list = torch.cat((pol_true_list, p_true), axis = 0)
                pol_pred_list = torch.cat((pol_pred_list, p_predict), axis = 0)
                
                if len(angles) == 4:           
                    az_predict, az_true = angles[2].squeeze(), angles[3].squeeze()
                    az_res = (az_predict - az_true).abs()
                    az_res = torch.where(az_res < 180, az_res, 360 - az_res)

                    az_res_list = torch.cat((az_res_list, az_res), axis = 0)  
                    az_true_list = torch.cat((az_true_list, az_true), axis = 0)
                    az_pred_list = torch.cat((az_pred_list, az_predict), axis = 0)
                    resolution_list = torch.cat((resolution_list, resolution), axis = 0)                    
        else:
            print("Emmmm.... What?")
        
    resolution_list = resolution_list.numpy()
    pol_res_list, az_res_list = pol_res_list.numpy(), az_res_list.numpy()   
    az_true_list, az_pred_list = az_true_list.numpy(), az_pred_list.numpy()      
    pol_true_list, pol_pred_list = pol_true_list.numpy(), pol_pred_list.numpy()
    print(az_true_list.min(), az_true_list.max())
    print("MAE azimut:", np.mean(np.abs(az_true_list - az_pred_list)))
    print(pol_true_list.min(), pol_true_list.max())
    print("MAE pol:", np.mean(np.abs(pol_true_list - pol_pred_list)))
    # drawing
    rows = 1 if az_pred_list.shape[0] == 0 else 3   
    plt.figure(figsize = (24, 8 * rows))   
    # polar  resolution
    plt.subplot(rows, 3, 1)
    polar_med = resolution_hist(resolution = pol_res_list, title = f'{regime} polar', x_max = 15)
    record['polar_res'] = polar_med
    # polar scatter
    plt.subplot(rows, 3, 2)
    polar_r2 =scatter_plot(true = pol_true_list, predict = pol_pred_list, title = f'{regime} polar',
                 r2 = r2_score(pol_true_list, pol_pred_list))
    record['polar_r2'] = polar_r2
    # polar distribution
    plt.subplot(rows, 3, 3)
    angle_hist(true = pol_true_list, predict = pol_pred_list, title = f'{regime} polar')
    
    if rows == 3: 
        # azimut  resolution
        plt.subplot(rows, 3, 4)
        azimut_res = resolution_hist(resolution = az_res_list, title = f'{regime} azimut', x_max = 45)
        record['azimut_res'] = azimut_res
        # azimut scatter
        plt.subplot(rows, 3, 5)
        scatter_plot(true = az_true_list, predict = az_pred_list, title = f'{regime} azimut')
        # azimut distribution
        plt.subplot(rows, 3, 6)
        angle_hist(true = az_true_list, predict = az_pred_list, title = f'{regime} azimut')
        # direction  resolution
        plt.subplot(rows, 3, 8)
        direction_res = resolution_hist(resolution = resolution_list, title = f'{regime} direction', x_max = 15)
        record['direction_res'] = direction_res
        
    if path_record != None:
        plt.savefig(path_record)
    ############         Metrics for  certain polar angle values   ###################
    if show_distr_by_polar_angle:
        metrics_by_angles(pol_true_list, pol_res_list, az_res_list, resolution_list,
                          bin_size = bin_size, angle = rows + 1, path = path_m_by_angle, show = show)        
    ##################################################################################    
    if not show:
        plt.close()
    else:
        plt.show()  
    return record
 
    
###########################################                  test_resolution           ##############    
def test_err_and_res(model, loader, mode = 'GNN'):
    error = 0
    _device = next(model.parameters()).device
    resolution_list = torch.tensor([])
    
    with torch.no_grad():       
        if mode == 'CNN': ############# CNN ###############################
            for x_batch, y_batch in loader:
                predict = model(x_batch.to(_device).float()).detach().cpu()     
                resolution, angles = outp_to_res_and_angles(predict, y_batch)          
                error += criterion(outp, y_batch).item() 
                if len(angles) == 4:           
                    resolution_list = torch.cat((resolution_list, resolution), axis = 0)
                    
                else:
                    p_predict, p_true = angles[0].squeeze(), angles[1].squeeze()
                    p_res = (p_predict - p_true).abs()
                    resolution_list = torch.cat((resolution_list, p_res), axis = 0)  
                    
        elif mode == 'GNN': ############# GNN ###############################
            for data in loader:
                data = data.to(_device)
                outp = model(data).detach().cpu()  
                
                if outp.shape[1] == 2:
                    y_batch = data.y_polar.squeeze().cpu()                    
                elif outp.shape[1] == 3:
                    y_batch = data.direction.squeeze().cpu()
                    
                resolution, angles = outp_to_res_and_angles(outp, y_batch) 
                error += criterion(outp, y_batch).item()  
                if len(angles) == 4:           
                    resolution_list = torch.cat((resolution_list, resolution), axis = 0)  
                    
                else:
                    p_predict, p_true = angles[0].squeeze(), angles[1].squeeze()
                    p_res = (p_predict - p_true).abs()
                    resolution_list = torch.cat((resolution_list, p_res), axis = 0)
        else:
            print("Emmmm.... What?")
    res = np.quantile(resolution_list.numpy(), q = 0.5)
    return res, error / len(loader)
    
'''
def GNN_Info(model, loader, regime = "train"):
    _device = next(model.parameters()).device
    pol_pred_list, pol_true_list, res_list = torch.tensor([]), torch.tensor([]), torch.tensor([])
    #angle_list = torch.tensor([])   
    for data in loader:
        #polar = torch.FloatTensor([hf[regime + '/ev_chars'][ind,0] * (np.pi) / 180])[None,:]
        #y_polar = torch.cat((torch.sin(polar), torch.cos(polar)), axis=1)
        v_pred = normalize(model( data.to(_device) ) ).cpu()
        p_pred = torch.acos(v_pred[:,-1]) 
        p_true = data.polar.squeeze().cpu()   
        pol_res = torch.abs(p_true - p_pred)
        res_list = torch.cat((res_list, pol_res), axis = 0)
        pol_true_list = torch.cat((pol_true_list, p_pred), axis = 0)
        pol_pred_list = torch.cat((pol_pred_list, p_true), axis = 0)
        
    res_list = (res_list / np.pi * 180).detach().numpy()
    #angle_list = (angle_list / np.pi * 180).detach().numpy()
    pol_pred_list = (pol_pred_list / np.pi * 180).detach().numpy()
    pol_true_list = (pol_true_list / np.pi * 180).detach().numpy()
'''
